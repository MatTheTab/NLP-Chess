# %% [markdown]
# # Data Reading Notebook

# %% [markdown]
# This notebook showcases how the data is read from the pgn file and trnasfrmed into a csv file suitable for being fed into a model or analyzed in later sections.

# %% [markdown]
# ## Imports

# %%
from utils.utils import *
import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Reading

# %%
train_data_path = "../Processed_Data\\NLP_Train.csv.gz"
val_data_path = "../Processed_Data\\NLP_Val.csv.gz"
test_data_path = "../Processed_Data\\NLP_Test.csv.gz"
stockfish_path = "../stockfish/stockfish-windows-x86-64-avx2.exe"

# %%
train_pgn_path = "../Data\\Train\\lichess_db_standard_rated_2013-08.pgn.zst"
save_data(pgn_file_path=train_pgn_path,
          save_file_path=train_data_path, max_num_games=20,
          stockfish_path=stockfish_path, shuffle=True)
# Out:
# Num processed games in a file = 20

# %%
test_pgn_path = "../Data\\Test\\lichess_db_standard_rated_2013-02.pgn.zst"
save_data(pgn_file_path=test_pgn_path,
          save_file_path=test_data_path, max_num_games=10,
          stockfish_path=stockfish_path, shuffle=True)
# Out:
# Num processed games in a file = 10

# %%
val_pgn_path = "../Data\\Val\\lichess_db_standard_rated_2013-01.pgn.zst"
save_data(pgn_file_path=val_pgn_path,
          save_file_path=val_data_path, max_num_games=10,
          stockfish_path=stockfish_path, shuffle=True)
# Out:
# Num processed games in a file = 10

# %%
train_data = pd.read_csv(train_data_path, compression='gzip')
val_data = pd.read_csv(val_data_path, compression='gzip')
test_data = pd.read_csv(test_data_path, compression='gzip')

# %% [markdown]
# ## Data Showcase

# %%
train_data.head()
# Out:
#    game_number  move_number  \
# 0           15           11
# 1            1           11
# 2           18           13
# 3            8           25
# 4            0           29
#
#                                                board  move  legal  \
# 0  r1bqk1nr/pppp1ppp/2n5/8/1bB1P3/2N2N2/PP3PPP/R1...  f1c4   True
# 1  r1bqkb1r/pp3ppp/2n1pn2/2pP4/8/P1NP3P/1PP2PP1/R...  e4d5   True
# 2  r1bqk2r/ppp2ppp/1Qn2n2/3p4/1bP5/2N5/PP1BPPPP/R...  d1b6  False
# 3  r4Pk1/1ppq1pp1/p1n2n1p/3p1p2/3P4/P1N1PN2/1PP2P...  h4f8  False
# 4  1Pk1r2r/p2nq1b1/1ppp1n1p/4p1p1/4P3/P2P1QBP/BPP...  f7b8  False
#
#    stockfish_2  stockfish_5  stockfish_10  move_quality_2  move_quality_5  \
# 0        -37.0        -37.0         -29.0           -25.0           -11.0
# 1        -64.0        -70.0         -62.0           -19.0           -25.0
# 2          NaN          NaN           NaN             NaN             NaN
# 3          NaN          NaN           NaN             NaN             NaN
# 4          NaN          NaN           NaN             NaN             NaN
#
#    ...  en_passant  halfmove_clock  fullmove_number  \
# 0  ...           -               2                6
# 1  ...           -               0                6
# 2  ...           -               1                7
# 3  ...           -               0               13
# 4  ...           -               0               15
#
#                                           prev_board  \
# 0  r1bqk1nr/pppp1ppp/2n5/8/1b2P3/2N2N2/PP3PPP/R1B...
# 1  r1bqkb1r/pp3ppp/2n1pn2/2pp4/4P3/P1NP3P/1PP2PP1...
# 2  r1bqk2r/ppp2ppp/2n2n2/3p4/1bP5/2N5/PP1BPPPP/R2...
# 3  r4rk1/1ppq1pp1/p1n2n1p/3p1p2/3P3P/P1N1PN2/1PP2...
# 4  2k1r2r/p2nqpb1/1ppp1n1p/4p1p1/4P3/P2P1QBP/BPP2...
#
#                                 prev_piece_placement prev_active_color  \
# 0  r1bqk1nr/pppp1ppp/2n5/8/1b2P3/2N2N2/PP3PPP/R1B...                 w
# 1  r1bqkb1r/pp3ppp/2n1pn2/2pp4/4P3/P1NP3P/1PP2PP1...                 w
# 2  r1bqk2r/ppp2ppp/2n2n2/3p4/1bP5/2N5/PP1BPPPP/R2...                 w
# 3  r4rk1/1ppq1pp1/p1n2n1p/3p1p2/3P3P/P1N1PN2/1PP2...                 w
# 4  2k1r2r/p2nqpb1/1ppp1n1p/4p1p1/4P3/P2P1QBP/BPP2...                 w
#
#   prev_castling_availability prev_en_passant  prev_halfmove_clock  \
# 0                       KQkq               -                    1
# 1                       KQkq               -                    0
# 2                       KQkq               -                    0
# 3                         KQ               -                    0
# 4                          -               -                    2
#
#    prev_fullmove_number
# 0                     6
# 1                     6
# 2                     7
# 3                    13
# 4                    15
#
# [5 rows x 27 columns]

# %%
val_data.head()
# Out:
#    game_number  move_number  \
# 0            4           37
# 1            5           54
# 2            7           44
# 3            6           11
# 4            9           76
#
#                                                board  move  legal  \
# 0  r4b1r/pp1bnkp1/1q2B3/2ppP2p/5P2/2PP1K1P/PP1N4/...  g4e6   True
# 1  Q3k1r1/2p2p1p/3pp2p/2r3p1/8/6P1/P2R1P2/5RK1 w ...  h2h7  False
# 2  1r2k2r/1p2np2/pNp3q1/2Pnp1pp/1P6/P2PQ2P/4BPP1/...  f6d5   True
# 3  r1bq1rk1/pppp1p1p/2P2n2/2b1p3/2B1P3/2PP1N2/PP3...  g7c6  False
# 4          8/5pk1/p1Q3b1/1p6/1q6/8/5PPK/8 w - - 0 39  a3b4   True
#
#    stockfish_2  stockfish_5  stockfish_10  move_quality_2  move_quality_5  \
# 0       -678.0       -747.0        -727.0           -73.0          -156.0
# 1          NaN          NaN           NaN             NaN             NaN
# 2       -235.0       -235.0        -244.0           -59.0           -70.0
# 3          NaN          NaN           NaN             NaN             NaN
# 4        507.0        507.0         504.0            27.0            30.0
#
#    ...  en_passant  halfmove_clock  fullmove_number  \
# 0  ...           -               0               19
# 1  ...           -               0               28
# 2  ...           -               0               23
# 3  ...           -               0                6
# 4  ...           -               0               39
#
#                                           prev_board  \
# 0  r4b1r/pp1bnkp1/1q2p3/2ppP2p/5PB1/2PP1K1P/PP1N4...
# 1  Q3k1r1/2p2p2/3pp2p/2r3p1/8/6P1/P2R1P1P/5RK1 b ...
# 2  1r2k2r/1p2np2/pNp2nq1/2PPp1pp/1P6/P2PQ2P/4BPP1...
# 3  r1bq1rk1/pppp1ppp/2n2n2/2b1p3/2B1P3/2PP1N2/PP3...
# 4         8/5pk1/p1Q3b1/1p6/1P6/q7/5PPK/8 b - - 0 38
#
#                                 prev_piece_placement prev_active_color  \
# 0  r4b1r/pp1bnkp1/1q2p3/2ppP2p/5PB1/2PP1K1P/PP1N4...                 w
# 1        Q3k1r1/2p2p2/3pp2p/2r3p1/8/6P1/P2R1P1P/5RK1                 b
# 2  1r2k2r/1p2np2/pNp2nq1/2PPp1pp/1P6/P2PQ2P/4BPP1...                 b
# 3  r1bq1rk1/pppp1ppp/2n2n2/2b1p3/2B1P3/2PP1N2/PP3...                 w
# 4                    8/5pk1/p1Q3b1/1p6/1P6/q7/5PPK/8                 b
#
#   prev_castling_availability prev_en_passant  prev_halfmove_clock  \
# 0                          -               -                    0
# 1                          -               -                    2
# 2                          k               -                    0
# 3                         KQ               -                    1
# 4                          -               -                    0
#
#    prev_fullmove_number
# 0                    19
# 1                    27
# 2                    22
# 3                     6
# 4                    38
#
# [5 rows x 27 columns]

# %%
test_data.head()
# Out:
#    game_number  move_number  \
# 0            4           11
# 1            1            3
# 2            3           26
# 3            7           33
# 4            7          114
#
#                                                board  move  legal  \
# 0  rnb1k1nr/ppp1ppbp/4q1p1/8/3P4/2N2N2/PPP1BPPP/R...  g1f3   True
# 1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PP1P1PPP/RNBQKBN...  c2f2  False
# 2  rnnq1rk1/1b3p1p/pp1p2p1/2p5/2P1PP2/N1b1B3/PP1Q...  g7c3   True
# 3  r6r/1p2b1pp/p4nk1/n3q3/2Q2N2/N1P1B3/PP3PPP/R3K...  e6f4   True
# 4                   8/8/K5pk/8/8/1P5p/8/8 w - - 0 58  h4h3   True
#
#    stockfish_2  stockfish_5  stockfish_10  move_quality_2  move_quality_5  \
# 0        117.0        119.0         129.0           -15.0           -14.0
# 1          NaN          NaN           NaN             NaN             NaN
# 2       -115.0       -115.0        -115.0           -19.0           -19.0
# 3        355.0        355.0         402.0           -32.0           -55.0
# 4        529.0        529.0         573.0           -21.0           -21.0
#
#    ...  en_passant  halfmove_clock  fullmove_number  \
# 0  ...           -               2                6
# 1  ...           -               0                2
# 2  ...           -               0               14
# 3  ...           -               4               17
# 4  ...           -               0               58
#
#                                           prev_board  \
# 0  rnb1k1nr/ppp1ppbp/4q1p1/8/3P4/2N5/PPP1BPPP/R1B...
# 1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
# 2  rnnq1rk1/1b3pbp/pp1p2p1/2p5/2P1PP2/N1N1B3/PP1Q...
# 3  r6r/1p2b1pp/p3Nnk1/n3q3/2Q5/N1P1B3/PP3PPP/R3K2...
# 4                   8/8/K5pk/8/7p/1P6/8/8 b - - 0 57
#
#                                 prev_piece_placement prev_active_color  \
# 0  rnb1k1nr/ppp1ppbp/4q1p1/8/3P4/2N5/PPP1BPPP/R1B...                 w
# 1    rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBNR                 w
# 2  rnnq1rk1/1b3pbp/pp1p2p1/2p5/2P1PP2/N1N1B3/PP1Q...                 b
# 3    r6r/1p2b1pp/p3Nnk1/n3q3/2Q5/N1P1B3/PP3PPP/R3K2R                 w
# 4                              8/8/K5pk/8/7p/1P6/8/8                 b
#
#   prev_castling_availability prev_en_passant  prev_halfmove_clock  \
# 0                       KQkq               -                    1
# 1                       KQkq               -                    0
# 2                          -               -                    1
# 3                         KQ               -                    3
# 4                          -               -                    0
#
#    prev_fullmove_number
# 0                     6
# 1                     2
# 2                    13
# 3                    17
# 4                    57
#
# [5 rows x 27 columns]

# %%
train_data.describe()
# Out:
#        game_number  move_number  stockfish_2  stockfish_5  stockfish_10  \
# count  2478.000000  2478.000000  1263.000000  1263.000000   1263.000000
# mean      9.654560    45.759483   -22.200317   -22.552652    -20.001584
# std       6.055866    39.042789   385.928666   391.287489    410.929608
# min       0.000000     1.000000 -1507.000000 -1507.000000  -1616.000000
# 25%       4.000000    16.000000  -179.000000  -182.000000   -193.500000
# 50%      10.000000    34.000000    -5.000000    -7.000000     -8.000000
# 75%      15.000000    64.000000   123.500000   115.500000    131.000000
# max      19.000000   179.000000  1279.000000  1279.000000   1507.000000
#
#        move_quality_2  move_quality_5  move_quality_10     prev_ELO  \
# count     1222.000000     1222.000000      1222.000000  1239.000000
# mean       -53.568740      -53.990180       -49.337152  1630.016949
# std        109.319314      109.939787       107.949260   240.843880
# min       -889.000000     -889.000000      -831.000000  1124.000000
# 25%        -75.750000      -70.750000       -63.000000  1483.000000
# 50%        -23.500000      -21.000000       -15.000000  1605.000000
# 75%         -1.000000        0.000000         0.000000  1752.000000
# max        383.000000      383.000000       611.000000  2223.000000
#
#        current_ELO  halfmove_clock  fullmove_number  prev_halfmove_clock  \
# count  2478.000000     2478.000000      2478.000000          2478.000000
# mean   1628.553672        1.232446        23.627119             1.828894
# std     241.692168        2.836986        19.524789             3.288537
# min    1124.000000        0.000000         1.000000             0.000000
# 25%    1463.000000        0.000000         9.000000             0.000000
# 50%    1605.000000        0.000000        18.000000             1.000000
# 75%    1752.000000        1.000000        33.000000             2.000000
# max    2223.000000       26.000000        90.000000            26.000000
#
#        prev_fullmove_number
# count           2478.000000
# mean              23.132365
# std               19.521202
# min                1.000000
# 25%                8.000000
# 50%               17.000000
# 75%               32.000000
# max               90.000000

# %%
val_data.describe()
# Out:
#        game_number  move_number  stockfish_2  stockfish_5  stockfish_10  \
# count  1080.000000  1080.000000   548.000000   548.000000    548.000000
# mean      5.305556    33.009259   -20.987226   -23.498175    -23.202555
# std       2.756939    23.221501   336.272646   341.360893    349.724390
# min       0.000000     1.000000  -899.000000  -899.000000   -899.000000
# 25%       3.000000    14.000000  -176.000000  -181.750000   -191.000000
# 50%       5.000000    28.500000   -14.500000   -18.000000    -21.500000
# 75%       8.000000    48.250000   121.750000   124.250000    123.000000
# max       9.000000    94.000000   900.000000   900.000000    900.000000
#
#        move_quality_2  move_quality_5  move_quality_10     prev_ELO  \
# count      528.000000      528.000000       528.000000   540.000000
# mean       -52.589015      -57.753788       -57.204545  1616.746296
# std        107.505825      124.402877       123.414452   213.822782
# min      -1168.000000    -1168.000000     -1164.000000  1169.000000
# 25%        -66.000000      -71.000000       -61.000000  1477.000000
# 50%        -29.000000      -25.500000       -21.000000  1541.000000
# 75%         -2.000000       -1.000000        -2.000000  1765.000000
# max        187.000000      301.000000       172.000000  1973.000000
#
#        current_ELO  halfmove_clock  fullmove_number  prev_halfmove_clock  \
# count  1080.000000     1080.000000      1080.000000          1080.000000
# mean   1616.475926        0.791667        17.251852             1.211111
# std     215.089596        1.427301        11.617295             1.646145
# min    1169.000000        0.000000         1.000000             0.000000
# 25%    1477.000000        0.000000         8.000000             0.000000
# 50%    1541.000000        0.000000        15.000000             1.000000
# 75%    1777.500000        1.000000        25.000000             2.000000
# max    1973.000000        9.000000        48.000000             8.000000
#
#        prev_fullmove_number
# count           1080.000000
# mean              16.757407
# std               11.609591
# min                1.000000
# 25%                7.000000
# 50%               14.500000
# 75%               24.250000
# max               47.000000

# %%
test_data.describe()
# Out:
#        game_number  move_number  stockfish_2  stockfish_5  stockfish_10  \
# count   934.000000   934.000000   471.000000   471.000000    471.000000
# mean      5.304069    34.010707   -21.772824   -24.874735    -23.755839
# std       2.804384    27.016447   241.032578   248.275463    248.297149
# min       0.000000     1.000000  -899.000000 -1011.000000   -985.000000
# 25%       3.000000    13.000000  -128.000000  -125.500000   -126.000000
# 50%       6.000000    28.000000    -7.000000    -7.000000     -8.000000
# 75%       7.000000    47.000000    85.500000    80.500000     78.000000
# max       9.000000   118.000000   900.000000   969.000000   1101.000000
#
#        move_quality_2  move_quality_5  move_quality_10     prev_ELO  \
# count      451.000000      451.000000       451.000000   467.000000
# mean       -52.215078      -58.594235       -56.875831  1605.672377
# std        115.819861      115.874595       114.302008   182.828157
# min       -867.000000     -869.000000      -927.000000  1212.000000
# 25%        -65.000000      -77.000000       -73.500000  1481.000000
# 50%        -24.000000      -26.000000       -22.000000  1631.000000
# 75%          0.000000       -0.500000        -2.000000  1796.000000
# max        175.000000      147.000000       116.000000  1876.000000
#
#        current_ELO  halfmove_clock  fullmove_number  prev_halfmove_clock  \
# count   934.000000      934.000000       934.000000           934.000000
# mean   1603.554604        0.794433        17.751606             1.162741
# std     184.531825        1.449593        13.514883             1.636685
# min    1212.000000        0.000000         1.000000             0.000000
# 25%    1481.000000        0.000000         7.000000             0.000000
# 50%    1631.000000        0.000000        15.000000             0.000000
# 75%    1796.000000        1.000000        24.000000             2.000000
# max    1876.000000       10.000000        60.000000            10.000000
#
#        prev_fullmove_number
# count            934.000000
# mean              17.259101
# std               13.506193
# min                1.000000
# 25%                7.000000
# 50%               14.000000
# 75%               24.000000
# max               59.000000

# %%
train_data['real'].value_counts()
# Out:
# real
# True     1239
# False    1239
# Name: count, dtype: int64

# %%
val_data['real'].value_counts()
# Out:
# real
# True     540
# False    540
# Name: count, dtype: int64

# %%
test_data['real'].value_counts()
# Out:
# real
# True     467
# False    467
# Name: count, dtype: int64

# %%
train_data['legal'].value_counts()
# Out:
# legal
# True     1263
# False    1215
# Name: count, dtype: int64

# %%
val_data['legal'].value_counts()
# Out:
# legal
# True     548
# False    532
# Name: count, dtype: int64

# %%
test_data['legal'].value_counts()
# Out:
# legal
# True     471
# False    463
# Name: count, dtype: int64

# %%
print(len(train_data))
# Out:
# 2478
