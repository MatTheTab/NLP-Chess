# %% [markdown]
# # Exploration of Human Chess Games - EDA

# %% [markdown]
# ## Imports

# %%
from utils.utils import *

# %% [markdown]
# ## Data Reading

# %%
train_data_path = "../Processed_Data\\NLP_Train.csv.gz"
val_data_path = "../Processed_Data\\NLP_Val.csv.gz"
test_data_path = "../Processed_Data\\NLP_Test.csv.gz"

# %%
train_data = pd.read_csv(train_data_path, compression='gzip')
val_data = pd.read_csv(val_data_path, compression='gzip')
test_data = pd.read_csv(test_data_path, compression='gzip')

# %% [markdown]
# ## Visualizations

# %%
calculate_performance(train_data)
# Out:
# stockfish_2: Human Mean = -22.41927555927479,         Random Mean = -127.47605542791499,         Human Std = 343.2319632114061,         Random Std = 372.65572458964056
# stockfish_5: Human Mean = -24.448678468778933,         Random Mean = -152.41445290063183,         Human Std = 348.0491804264299,         Random Std = 392.0092054599812
# stockfish_10:         Human Mean = -21.40742263871607,         Random Mean = -149.72914273406087,         Human Std = 356.0450560367044,         Random Std = 407.5572762873279
# move_quality_2:         Human Mean = -53.29044001795769,         Random Mean = -237.3816766118469,         Human Std = 105.04862968333302,         Random Std = 238.45454622424546
# move_quality_5:         Human Mean = -57.46722915433113,         Random Mean = -264.95404599039443,         Human Std = 115.77678380838788,         Random Std = 265.1726499020755
# ...

# %%
get_move_quality_histogram(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:522: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
get_position_quality_histogram(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:476: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
violin_plot_moves(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:557: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(fontsize=12)
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:572: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend(fontsize=12)
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:587: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[2].legend(fontsize=12)

# %%
violin_plot_positions(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:625: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(fontsize=12)
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:640: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend(fontsize=12)
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:655: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[2].legend(fontsize=12)

# %%
plot_most_common_moves(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:743: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plot_legal_illegal(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:714: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plot_real_fake(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:686: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plot_correlation_heatmap(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:761: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['current_ELO'] = pd.to_numeric(
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['prev_ELO'] = pd.to_numeric(human_df['prev_ELO'], errors='coerce')

# %%
plot_elo_move_quality(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:794: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['current_ELO'] = pd.to_numeric(
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:796: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['prev_ELO'] = pd.to_numeric(human_df['prev_ELO'], errors='coerce')
# ...

# %%
plot_elo_position_quality(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['current_ELO'] = pd.to_numeric(
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:855: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['prev_ELO'] = pd.to_numeric(human_df['prev_ELO'], errors='coerce')
# ...

# %%
plot_ELO_move_quality_3D(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:912: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['prev_ELO'] = pd.to_numeric(human_df['prev_ELO'], errors='coerce')

# %%
plot_ELO_position_quality_3D(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:945: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['current_ELO'] = pd.to_numeric(

# %%
plot_most_common_moves_per_ELO(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:979: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['prev_ELO'] = pd.to_numeric(human_df['prev_ELO'], errors='coerce')
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:982: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['player_level'] = pd.cut(

# %%
plot_most_common_moves_per_ELO_relative(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:1055: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['prev_ELO'] = pd.to_numeric(human_df['prev_ELO'], errors='coerce')
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:1058: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['player_level'] = pd.cut(

# %%
plot_most_common_moves_per_ELO_colors(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:1141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['prev_ELO'] = pd.to_numeric(human_df['prev_ELO'], errors='coerce')
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:1144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['player_level'] = pd.cut(

# %%
plot_most_common_moves_per_ELO_relative_colors(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:1218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['prev_ELO'] = pd.to_numeric(human_df['prev_ELO'], errors='coerce')
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:1221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['player_level'] = pd.cut(

# %%
plot_most_common_move_evaluations(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:1303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['prev_ELO'] = pd.to_numeric(human_df['prev_ELO'], errors='coerce')
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:1306: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['player_level'] = pd.cut(

# %%
plot_most_common_move_evaluations_color(train_data)
# Out:
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:1406: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['prev_ELO'] = pd.to_numeric(human_df['prev_ELO'], errors='coerce')
# d:\NLP_Chess\Repo\NLP-Chess\data_analysis\utils\utils.py:1409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_df['player_level'] = pd.cut(

# %%
plot_move_quality__random_human_3D(train_data)

# %%
plot_position_quality__random_human_3D(train_data)
