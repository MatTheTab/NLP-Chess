# %%
from utils.utils import *

# %%
train_data_path = "D:\\NLP_Chess\\Processed_Data\\NLP_Train.csv.gz"
val_data_path = "D:\\NLP_Chess\\Processed_Data\\NLP_Val.csv.gz"
test_data_path = "D:\\NLP_Chess\\Processed_Data\\NLP_Test.csv.gz"
stockfish_path = "D:\\NLP_Chess\\stockfish\\stockfish-windows-x86-64-avx2.exe"

# %%
save_data(pgn_file_path = "D:\\NLP_Chess\\Data\\Train\\lichess_db_standard_rated_2013-08.pgn.zst", save_file_path = train_data_path, max_num_games = 20000, stockfish_path=stockfish_path, shuffle=True)
# Out:
# d:\NLP_Chess\utils\utils.py:29: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_games_df = pd.concat([all_games_df, data_df], ignore_index=True)
# Num processed games in a file = 20000

# %%
save_data(pgn_file_path = "D:\\NLP_Chess\\Data\\Test\\lichess_db_standard_rated_2013-02.pgn.zst", save_file_path = test_data_path, max_num_games = 1000, stockfish_path = stockfish_path, shuffle=True)
# Out:
# d:\NLP_Chess\utils\utils.py:29: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_games_df = pd.concat([all_games_df, data_df], ignore_index=True)
# Num processed games in a file = 1000

# %%
save_data(pgn_file_path = "D:\\NLP_Chess\\Data\\Val\\lichess_db_standard_rated_2013-01.pgn.zst", save_file_path = val_data_path, max_num_games = 1000, stockfish_path = stockfish_path, shuffle=True)
# Out:
# Num processed games in a file = 1000

# %%
train_data = pd.read_csv(train_data_path, compression='gzip')
val_data = pd.read_csv(val_data_path, compression='gzip')
test_data = pd.read_csv(test_data_path, compression='gzip')

# %%
train_data.head()
# Out:
#    game_number  move_number  \
# 0         8610           74
# 1        14299           76
# 2        11736           55
# 3        12785           62
# 4         8175           66
#
#                                                board  move  legal  \
# 0    3rQ2k/p4Q1p/1p6/8/3R3p/8/PPP3PP/5RK1 w - - 1 38  g7d8  False
# 1   8/6p1/5p1p/1p1p1P2/1P1K1kP1/P6P/5p2/8 w - - 0 39  f3f2  False
# 2  4rb2/5kp1/1p1p1pp1/2pP4/P1P3R1/1PB3PP/5PK1/6P1...  a6g1  False
# 3  1r3k2/p4p2/2B2p2/P2Pp3/4PnR1/4KP1p/5P1P/8 w - ...  c8b8   True
# 4       6k1/6pp/p7/3bKp2/1p6/1P2R3/P7/6r1 w - - 0 34  e6f5   True
#
#    stockfish_2  stockfish_5  stockfish_10  move_quality_2  move_quality_5  \
# 0          NaN          NaN           NaN             NaN             NaN
# 1          NaN          NaN           NaN             NaN             NaN
# 2          NaN          NaN           NaN             NaN             NaN
# 3        108.0        139.0         115.0            14.0            54.0
# ...

# %%
val_data.head()
# Out:
#    game_number  move_number  \
# 0          601           63
# 1          859          136
# 2          161           57
# 3           70           64
# 4          968           35
#
#                                                board  move  legal  \
# 0  8/pnp2pk1/1p1q2p1/rP4Q1/4R3/6PP/5P2/4R1K1 b - ...  g2g3   True
# 1            3Q4/4n3/5kp1/7p/6r1/8/5K2/8 w - - 24 69  f5e7   True
# 2    r3r1k1/pp4pb/7p/7P/1PP1p1P1/2K5/P7/8 b - - 1 29  d2c3   True
# 3    2rkr3/5p2/n1bB4/p2p3p/4nR1P/3K4/P7/8 w - - 6 33  h8e8   True
# 4  2rq1rk1/1b1nnpb1/1p2p1p1/pP1p3p/P2P4/2NBPP2/1B...  g4f2   True
#
#    stockfish_2  stockfish_5  stockfish_10  move_quality_2  move_quality_5  \
# 0        227.0        165.0         247.0          -158.0          -220.0
# 1         21.0         21.0          11.0            16.0            13.0
# 2       -701.0       -692.0        -989.0           -46.0           -13.0
# 3        723.0        753.0         771.0           -38.0            -8.0
# ...

# %%
test_data.head()
# Out:
#    game_number  move_number  \
# 0          895           45
# 1          959           50
# 2          465           34
# 3          768           32
# 4          641            9
#
#                                                board  move  legal  \
# 0  r5k1/5pbp/1p4P1/1N1Pp3/1pP1P1b1/1Q1B4/P5PP/5RK...  a5g6  False
# 1  r5k1/p2Q1pp1/n7/4p2p/3b4/2KP4/PP2q2P/RN5R w - ...  e3d4   True
# 2  2k1rb1r/pp1nqppp/b1p5/3pP3/1P3P2/2P3PP/P1QN2B1...  d8e8   True
# 3  r2q1rk1/1p2bpp1/p1n1pnbp/8/3P3B/P1NQ1P2/1PB1N1...  h5g6   True
# 4  rnb1kbnr/ppp2ppp/3p1q2/8/2NPp3/4P3/PPP2PPP/RNB...  e5c4   True
#
#    stockfish_2  stockfish_5  stockfish_10  move_quality_2  move_quality_5  \
# 0          NaN          NaN           NaN             NaN             NaN
# 1        757.0        757.0         681.0           -77.0           -77.0
# 2       -275.0       -275.0        -290.0           -27.0           -24.0
# 3        153.0        182.0         135.0           112.0           141.0
# ...

# %%
train_data.describe()
# Out:
#         game_number   move_number   stockfish_2   stockfish_5  stockfish_10  \
# count  2.650486e+06  2.650486e+06  1.353099e+06  1.353099e+06  1.353099e+06
# mean   1.002128e+04  4.151673e+01 -2.458206e+01 -2.708309e+01 -2.404916e+01
# std    5.768842e+03  3.075528e+01  3.441864e+02  3.494825e+02  3.576447e+02
# min    0.000000e+00  1.000000e+00 -1.918000e+03 -1.918000e+03 -1.634000e+03
# 25%    5.003000e+03  1.700000e+01 -2.000000e+02 -2.140000e+02 -2.170000e+02
# 50%    9.956000e+03  3.600000e+01 -1.000000e+01 -1.300000e+01 -1.300000e+01
# 75%    1.502700e+04  5.900000e+01  1.330000e+02  1.320000e+02  1.410000e+02
# max    1.999900e+04  2.390000e+02  2.538000e+03  1.872000e+03  1.634000e+03
#
#        move_quality_2  move_quality_5  move_quality_10  halfmove_clock  \
# count    1.312727e+06    1.312727e+06     1.312727e+06    2.650486e+06
# mean    -5.714468e+01   -6.181129e+01    -5.581604e+01    1.118049e+00
# ...

# %%
val_data.describe()
# Out:
#          game_number    move_number   stockfish_2   stockfish_5  stockfish_10  \
# count  122338.000000  122338.000000  62464.000000  62464.000000  62464.000000
# mean      499.390639      38.615017    -25.873607    -28.202485    -25.769723
# std       290.979365      29.141178    369.275961    374.564383    382.531522
# min         0.000000       1.000000  -1470.000000  -1486.000000  -1366.000000
# 25%       243.000000      16.000000   -219.000000   -234.000000   -238.000000
# 50%       507.000000      33.000000    -12.000000    -15.000000    -15.000000
# 75%       751.000000      54.000000    149.000000    150.000000    159.000000
# max       999.000000     186.000000   1727.000000   1780.000000   1388.000000
#
#        move_quality_2  move_quality_5  move_quality_10  halfmove_clock  \
# count    60451.000000    60451.000000     60451.000000   122338.000000
# mean       -60.954145      -65.247754       -60.404311        1.003327
# ...

# %%
test_data.describe()
# Out:
#          game_number    move_number   stockfish_2   stockfish_5  stockfish_10  \
# count  130112.000000  130112.000000  66440.000000  66440.000000  66440.000000
# mean      500.405604      40.707375    -25.708278    -28.208669    -25.894190
# std       290.514289      30.535309    351.591560    356.947142    365.055476
# min         0.000000       1.000000  -1427.000000  -1427.000000  -1395.000000
# 25%       251.000000      17.000000   -210.000000   -222.000000   -226.000000
# 50%       499.000000      35.000000    -11.000000    -14.000000    -14.000000
# 75%       752.000000      57.000000    140.000000    140.000000    146.000000
# max       999.000000     202.000000   1585.000000   1535.000000   1383.000000
#
#        move_quality_2  move_quality_5  move_quality_10  halfmove_clock  \
# count    64418.000000    64418.000000     64418.000000   130112.000000
# mean       -58.975504      -63.582725       -58.971732        1.120442
# ...

# %%
train_data['real'].value_counts()
# Out:
# real
# False    1325243
# True     1325243
# Name: count, dtype: int64

# %%
val_data['real'].value_counts()
# Out:
# real
# True     61169
# False    61169
# Name: count, dtype: int64

# %%
test_data['real'].value_counts()
# Out:
# real
# False    65056
# True     65056
# Name: count, dtype: int64

# %%
train_data['legal'].value_counts()
# Out:
# legal
# True     1353099
# False    1297387
# Name: count, dtype: int64

# %%
val_data['legal'].value_counts()
# Out:
# legal
# True     62464
# False    59874
# Name: count, dtype: int64

# %%
test_data['legal'].value_counts()
# Out:
# legal
# True     66440
# False    63672
# Name: count, dtype: int64

# %%
print(len(train_data))
# Out:
# 2650486
